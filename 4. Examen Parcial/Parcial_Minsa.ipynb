# %%
import numpy as np              # Manipulacion de estuctura
import pandas as pd             # Manipulacion de CSV
import matplotlib.pyplot as plt # Graficos

# %%
!7z x vacunas_covid.7z
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 319537895 bytes (305 MiB)
#
# Extracting archive: vacunas_covid.7z
# --
# Path = vacunas_covid.7z
# Type = 7z
# Physical Size = 319537895
# Headers Size = 138
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       3510100698
# Compressed: 319537895

# %%
# leemos los datos de un conjunto de datos
data_minsa = pd.read_csv('vacunas_covid.csv')
# Imprimimos las 5 filas iniciales en los datos
data_minsa.tail()
# Out:
#           FECHA_CORTE      UUID  ... PROVINCIA              DISTRITO
# 31858509     20211017  27902118  ...      LIMA     SANTIAGO DE SURCO
# 31858510     20211017   5339324  ...      LIMA     SANTIAGO DE SURCO
# 31858511     20211017  21192635  ...      LIMA  SAN MARTIN DE PORRES
# 31858512     20211017   5339329  ...      LIMA     SANTIAGO DE SURCO
# 31858513     20211017  11613459  ...     CUSCO               WANCHAQ
#
# [5 rows x 12 columns]

# %%
data_minsa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31858514 entries, 0 to 31858513
# Data columns (total 12 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   FECHA_CORTE       int64
#  1   UUID              int64
#  2   GRUPO_RIESGO      object
#  3   EDAD              int64
#  4   SEXO              object
#  5   FECHA_VACUNACION  int64
#  6   DOSIS             int64
#  7   FABRICANTE        object
#  8   DIRESA            object
#  9   DEPARTAMENTO      object
#  10  PROVINCIA         object
#  11  DISTRITO          object
# dtypes: int64(5), object(7)
# memory usage: 2.8+ GB

# %%
# Distribuciones de cada variable
# %matplotlib inline
import matplotlib.pyplot as plt
data_minsa.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# Distribuciones de cada variable
# %matplotlib inline
x = data_minsa["EDAD"]
y = data_minsa["FABRICANTE"]
plt.scatter(x,y)
plt.show()

# %%
print(max(data["EDAD"]))
# Out:
# 224
